# %%
import tensorflow as tf
import os
import numpy as np
import pickle
import cv2 as cv

# %%
# file_path = 'E:\\GPImage\\HandleImage\\Train_Enhance_Image\\'

# classifyPath = 'E:\\GPImage\\HandleImage\\EnhanceImage\\'

# testPath = 'E:\\GPImage\\HandleImage\\Test_Enhance_Image\\'

# savePath = 'E:\\GPImage\\HandleImage\\HandleEnhanceImage\\'

# %%
#  加载数据   
# class Data:
#     def __init__(self, filenames, need_shuffle):
#         all_data = []
#         all_labels = []
#         path = filenames
#         fileList = os.listdir(filenames)
#         totalNum = len(fileList)
#         for i in range(totalNum):
            
#             iPath = path + str(fileList[i])
#             # print(iPath)
#             #  添加 文件标签
#             # 获取文件名
#             y = fileList[i]
#             # 去除文件后缀
#             y = os.path.splitext(y)
#             y_ = y[0]
#             # 去除文件中的数字，获取文件标签
#             y_ = "".join(filter(str.isalpha, y_))
#             if(y_ == 'eye'):
#                 y_label = 1
#             elif(y_ == 'back'):
#                 y_label = 2
#             elif(y_ == 'face'):
#                 y_label = 3
#             elif(y_ == 'left'):
#                 y_label = 4
#             else:
#                 y_label = 5
#             #   添加文件图片数据 
#             src = cv.imread(iPath)
#             image = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
           
#             image = cv.resize(
#                               image, 
#                               (256, 256),
#                               interpolation=cv.INTER_AREA
#                              )  
            
#             image = image.flatten()
#             all_data.append(image)
#             all_labels.append(y_label)
            
            
#         self._data = np.vstack(all_data)
#         # 将数据缩放到[-1, 1]
#         self._data = self._data / 127.5 - 1
#         self._labels = np.hstack(all_labels)
        
#         print(self._data.shape)
#         print(self._labels.shape)
        
#         self._num_examples = self._data.shape[0]
#         self._need_shuffle = need_shuffle
        
#         self._indicator = 0  # 当前遍历到的位置
#         if self._need_shuffle:
#             self._shuffle_data()
        
        
#     """打乱训练数据集"""
#     def _shuffle_data(self):
#         p = np.random.permutation(self._num_examples)
#         self._data = self._data[p]
#         self._labels = self._labels[p]
        
#     """返回batch_size个样本"""
#     def next_batch (self, batch_size):
#         end_indicator = self._indicator + batch_size
#         if end_indicator > self._num_examples:
#             if self._need_shuffle:
#                 self._shuffle_data()
#                 self._indicator = 0
#                 end_indicator = batch_size
#             else:
#                 raise Exception("have no more examples")
#         if end_indicator > self._num_examples:
#             raise Exception("batch_size is larger than all examples")
#         batch_data = self._data[self._indicator: end_indicator]
#         batch_labels = self._labels[self._indicator: end_indicator]
#         self._indicator = end_indicator
#         return batch_data, batch_labels
    
"""加载数据"""  
# train_data = Data(filenames=file_path, need_shuffle=True)
# test_data = Data(filenames=testPath, need_shuffle=True)
# classify_data = Data(filenames=classifyPath, need_shuffle=False)
# Out:
# (7500, 65536)
# (7500,)
# (1500, 65536)
# (1500,)
# (2433, 65536)
# (2433,)

# %%
# x = tf.placeholder(tf.float32, [None, 65536], name = 'x_input')
# y = tf.placeholder(tf.int64, [None], name = 'y_input')

# %%
# # 各层参数设置
# x_image = tf.reshape(x, [-1, 1, 256, 256])
# # 256 * 256
# x_image = tf.transpose(x_image,  perm=[0, 2, 3, 1])

# conv1_1 = tf.layers.conv2d(x_image, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            name='conv1_1',
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu,
#                            reuse=tf.AUTO_REUSE)

# conv1_2 = tf.layers.conv2d(conv1_1, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv1_2',
#                            reuse=tf.AUTO_REUSE)
    
# # 128 * 128
# pooling1 = tf.layers.max_pooling2d(conv1_2, 
#                                   (2, 2), # 核大小
#                                   (2, 2), # 步长
#                                   name='pool1')

# pooling1 = tf.layers.dropout(pooling1, 
#                              rate = 0.5,
#                              noise_shape=None,
#                              seed=None,
#                              training=False,
#                              name=None )

# conv2_1 = tf.layers.conv2d(pooling1, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv2_1',
#                            reuse=tf.AUTO_REUSE)

# conv2_2 = tf.layers.conv2d(conv2_1, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv2_2',
#                            reuse=tf.AUTO_REUSE)

# # 64 * 64
# pooling2 = tf.layers.max_pooling2d(conv2_2, 
#                                   (2, 2), # 核大小
#                                   (2, 2), # 步长
#                                   name='pool2')

# pooling2 = tf.layers.dropout(pooling2, 
#                              rate = 0.5,
#                              noise_shape=None,
#                              seed=None,
#                              training=False,
#                              name=None )

# conv3_1 = tf.layers.conv2d(pooling2, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv3_1',
#                            reuse=tf.AUTO_REUSE)

# conv3_2 = tf.layers.conv2d(conv3_1, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv3_2',
#                            reuse=tf.AUTO_REUSE)

# # 32 * 32
# pooling3 = tf.layers.max_pooling2d(conv3_2, 
#                                   (2, 2), # 核大小
#                                   (2, 2), # 步长
#                                   name='pool3')

# pooling3 = tf.layers.dropout(pooling3, 
#                              rate = 0.5,
#                              noise_shape=None,
#                              seed=None,
#                              training=False,
#                              name=None )


# # -------------------------------------------
# conv4_1 = tf.layers.conv2d(pooling3, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv4_1',
#                            reuse=tf.AUTO_REUSE)

# conv4_2 = tf.layers.conv2d(conv4_1, 
#                            32, # 卷积核输出的通道数
#                            (3, 3), #卷积核的大小
#                            padding='same', #使用padding 使得图片输出大小相等
#                            activation=tf.nn.relu, 
#                            name='conv4_2',
#                            reuse=tf.AUTO_REUSE)

# # 16 * 16
# pooling4 = tf.layers.max_pooling2d(conv4_2, 
#                                   (2, 2), # 核大小
#                                   (2, 2), # 步长
#                                   name='pool4')

# pooling4 = tf.layers.dropout(pooling4, 
#                              rate = 0.5,
#                              noise_shape=None,
#                              seed=None,
#                              training=False,
#                              name=None )

# # -------------------------------------------


# #[None, 32 * 32 * 32]
# flatten = tf.layers.flatten(pooling4)

#  10 -》 5
# y_ = tf.layers.dense(flatten, 5)


# """交叉熵损失函数"""
# loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)
# # y_ -> sofmax
# # y -> one_hot
# # loss = ylogy_


# #indices
# predict = tf.arg_max(y_, 1, name = 'output')
# corrent_preicttion = tf.equal(predict, y)
# #准确率
# accuracy = tf.reduce_mean(tf.cast(corrent_preicttion, tf.float64))


# #梯度下降
# with tf.name_scope('train_op'):
#     train_op = tf.train.AdamOptimizer(learning_rate=0.001 ,epsilon=1e-4).minimize(loss)

# %%
# 各层参数设置
x_image = tf.reshape(x, [-1, 1, 256, 256])
# 256 * 256
x_image = tf.transpose(x_image,  perm=[0, 2, 3, 1])

conv1_1 = tf.layers.conv2d(x_image, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           name='conv1_1',
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu,
                           reuse=tf.AUTO_REUSE)

conv1_2 = tf.layers.conv2d(conv1_1, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv1_2',
                           reuse=tf.AUTO_REUSE)
    
# 128 * 128
pooling1 = tf.layers.max_pooling2d(conv1_2, 
                                  (2, 2), # 核大小
                                  (2, 2), # 步长
                                  name='pool1')

conv2_1 = tf.layers.conv2d(pooling1, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv2_1',
                           reuse=tf.AUTO_REUSE)

conv2_2 = tf.layers.conv2d(conv2_1, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv2_2',
                           reuse=tf.AUTO_REUSE)

# 64 * 64
pooling2 = tf.layers.max_pooling2d(conv2_2, 
                                  (2, 2), # 核大小
                                  (2, 2), # 步长
                                  name='pool2')

conv3_1 = tf.layers.conv2d(pooling2, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv3_1',
                           reuse=tf.AUTO_REUSE)

conv3_2 = tf.layers.conv2d(conv3_1, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv3_2',
                           reuse=tf.AUTO_REUSE)

conv3_3 = tf.layers.conv2d(conv3_2, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv3_3',
                           reuse=tf.AUTO_REUSE)

# 32 * 32
pooling3 = tf.layers.max_pooling2d(conv3_3, 
                                  (2, 2), # 核大小
                                  (2, 2), # 步长
                                  name='pool3')

# -------------------------------------------
conv4_1 = tf.layers.conv2d(pooling3, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv4_1',
                           reuse=tf.AUTO_REUSE)

conv4_2 = tf.layers.conv2d(conv4_1, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv4_2',
                           reuse=tf.AUTO_REUSE)

conv4_3 = tf.layers.conv2d(conv4_2, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv4_3',
                           reuse=tf.AUTO_REUSE)

# 16 * 16
pooling4 = tf.layers.max_pooling2d(conv4_3, 
                                  (2, 2), # 核大小
                                  (2, 2), # 步长
                                  name='pool4')
# -------------------------------------------------------------

conv5_1 = tf.layers.conv2d(pooling4, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv5_1',
                           reuse=tf.AUTO_REUSE)

conv5_2 = tf.layers.conv2d(conv5_1, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv5_2',
                           reuse=tf.AUTO_REUSE)

conv5_3 = tf.layers.conv2d(conv5_2, 
                           32, # 卷积核输出的通道数
                           (3, 3), #卷积核的大小
                           padding='same', #使用padding 使得图片输出大小相等
                           activation=tf.nn.relu, 
                           name='conv5_3',
                           reuse=tf.AUTO_REUSE)

# 16 * 16
pooling5 = tf.layers.max_pooling2d(conv5_3, 
                                  (2, 2), # 核大小
                                  (2, 2), # 步长
                                  name='pool5')


#[None, 32 * 32 * 32]
flatten = tf.layers.flatten(pooling5)

y_ = tf.layers.dense(flatten, 5)


"""交叉熵损失函数"""
loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)
# y_ -> sofmax
# y -> one_hot
# loss = ylogy_


#indices
predict = tf.arg_max(y_, 1, name = 'output')
corrent_preicttion = tf.equal(predict, y)
#准确率
accuracy = tf.reduce_mean(tf.cast(corrent_preicttion, tf.float64))


#梯度下降
with tf.name_scope('train_op'):
    train_op = tf.train.AdamOptimizer(learning_rate=0.001 ,epsilon=1e-4).minimize(loss)
# Out:
# WARNING:tensorflow:From <ipython-input-6-21b78e97bda5>:157: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead

# %%
# # 初始化函数
# init = tf.global_variables_initializer() 
# batch_size = 50
# batch_steps = 1200
# test_steps = 50

# # 保存精度最高的模型(最近的1次)
# saver = tf.train.Saver(max_to_keep=1)
# saver_max_acc = 0
# saver_min_loss = 1
# savePath = 'E://GPImage//HandleImage//model.ckpt'

# #实例化session
# with tf.Session() as sess:
#     sess.run(init)
#     for j in range(5):
#         for i in range(batch_steps):
#             batch_data, batch_labels = train_data.next_batch(batch_size)
#             loss_val, acc_val, _ = sess.run([loss, accuracy, train_op], feed_dict={x: batch_data, y: batch_labels})
#             if (i+1) % 100 == 0:
#                 print('[Train] Step: %d 批  %d, loss: %4.5f, acc: %4.5f' % (j+1, i+1, loss_val, acc_val))
        
#             #每500次进行一次测试
#             if (i+1) % 500 == 0:
            
#                 all_test_acc_val = []
#                 all_test_loss = []
#                 for j in range(test_steps):
#                     test_batch_data, test_batch_labels = test_data.next_batch(batch_size)
#                     test_acc_val, test_loss_val = sess.run([accuracy, loss], feed_dict = {x: test_batch_data, y: test_batch_labels})
#                     all_test_acc_val.append(test_acc_val)
#                     all_test_loss.append(test_loss_val)
        
#                 test_acc = np.mean(all_test_acc_val)
#                 test_loss = np.mean(all_test_loss)
#                 print("----------------------------------------")
#                 print('[Test] Step: %d 批  %d, loss: %4.5f, acc: %4.5f' %( j+1, i+1, test_loss, test_acc))
#                 print("----------------------------------------")
            
#                 if(test_acc > saver_max_acc and test_loss < saver_min_loss):
#                     saver = tf.train.Saver()
#                     saver.save(sess, 'E:\\GPImage\\HandleImage\\model\\iris_model.ckpt', global_step=i+1)
#                     print('模型已保存')
    
# sess.close()
# Out:
# [Train] Step: 1 批  100, loss: 0.93722, acc: 0.66000
# [Train] Step: 1 批  200, loss: 0.39025, acc: 0.84000
# [Train] Step: 1 批  300, loss: 0.38378, acc: 0.84000
# [Train] Step: 1 批  400, loss: 0.42795, acc: 0.90000
# [Train] Step: 1 批  500, loss: 0.14688, acc: 0.94000
# ----------------------------------------
# [Test] Step: 50 批  500, loss: 0.18222, acc: 0.93200
# ----------------------------------------
# 模型已保存
# [Train] Step: 50 批  600, loss: 0.20836, acc: 0.94000
# [Train] Step: 50 批  700, loss: 0.09628, acc: 0.98000
# [Train] Step: 50 批  800, loss: 0.15766, acc: 0.96000
# [Train] Step: 50 批  900, loss: 0.03757, acc: 1.00000
# [Train] Step: 50 批  1000, loss: 0.15281, acc: 0.98000
# ----------------------------------------
# [Test] Step: 50 批  1000, loss: 0.20828, acc: 0.91280
# ----------------------------------------
# 模型已保存
# [Train] Step: 50 批  1100, loss: 0.10294, acc: 0.96000
# [Train] Step: 50 批  1200, loss: 0.01954, acc: 1.00000
# [Train] Step: 2 批  100, loss: 0.02749, acc: 1.00000
# [Train] Step: 2 批  200, loss: 0.02085, acc: 1.00000
# [Train] Step: 2 批  300, loss: 0.11284, acc: 0.98000
# [Train] Step: 2 批  400, loss: 0.19914, acc: 0.94000
# [Train] Step: 2 批  500, loss: 0.02261, acc: 1.00000
# ----------------------------------------
# [Test] Step: 50 批  500, loss: 0.04015, acc: 0.98320
# ----------------------------------------
# 模型已保存
# [Train] Step: 50 批
# ----------------------------------------
# 模型已保存
# [Train] Step: 50 批  600, loss: 0.00733, acc: 1.00000
# [Train] Step: 50 批  700, loss: 0.00031, acc: 1.00000
# [Train] Step: 50 批  800, loss: 0.04507, acc: 0.98000
# [Train] Step: 50 批  900, loss: 0.12333, acc: 0.94000
# [Train] Step: 50 批  1000, loss: 0.01478, acc: 0.98000
# ----------------------------------------
# [Test] Step: 50 批  1000, loss: 0.00147, acc: 1.00000
# ----------------------------------------
# 模型已保存
# [Train] Step: 50 批  1100, loss: 0.00245, acc: 1.00000
# [Train] Step: 50 批  1200, loss: 0.04876, acc: 0.98000

# %%
# # 准备分类数据
# fileList = os.listdir(classifyPath)
# totalNum = len(fileList)

# %%
# # 实现分类 
# # 初始化函数
# init = tf.global_variables_initializer() 
# batch_size = 1
# batch_steps = 2283

# images_data = test_data

# #实例化session
# with tf.Session() as sess:
#     sess.run(init)
#     new_saver = tf.train.import_meta_graph('E://GPImage//HandleImage//model/iris_model.ckpt-700.meta')
#     new_saver.restore(sess, tf.train.latest_checkpoint('E://GPImage//HandleImage//model/'))
#     for i in range(batch_steps):
#         batch_data, batch_labels = test_data.next_batch(batch_size)
#         graph = tf.get_default_graph()
#         logits = graph.get_tensor_by_name("output:0")
#         x = graph.get_tensor_by_name("x_input:0")
#         print("输入数据获取完毕")
#         print("-----------------------")    
#         print("运算开始")
    
#         classification_result = sess.run(
#                                      fetches = logits,
#                                      feed_dict={x: batch_data}
#                                         )
#         print("-----------------------")
#         print("运算结束，输出预测")
#         #打印出预测矩阵
#         print(classification_result)
#         #根据索引通过字典对应分类
    
#         output = classification_result
#         print("-----------保存图片准备-----------")
        
#         iPath = classifyPath + str(fileList[i])
#         image_i = cv.imread(iPath)
# #         image_i = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
#         savePath = "E:\\GPImage\\HandleImage\\HandleEnhanceImage\\"
#         if output[0]== 1:
#             path = savePath + 'BACK\\'
#             name = path + str(fileList[i])
#             print(name + " 保存文件路径")
#             cv.imwrite(name, image_i) 
#         elif output[0] == 2:
#             path = savePath + 'EYE\\'
#             name = path + str(fileList[i])
#             print(name + " 保存文件路径")
#             cv.imwrite(name, image_i) 
#         elif output[0] == 3:
#             path = savePath + 'FACE\\'
#             name = path + str(fileList[i])
#             print(name + " 保存文件路径")
#             cv.imwrite(name, image_i) 
#         elif output[0] == 4:
#             path = savePath + 'LEFT\\'
#             name = path + str(fileList[i])
#             print(name + " 保存文件路径")
#             cv.imwrite(name, image_i) 
#         else:
#             path = savePath + 'UP\\'
#             name = path + str(fileList[i]) 
#             print(name + " 保存文件路径")
#             cv.imwrite(name, image_i)
# Out:
# INFO:tensorflow:Restoring parameters from E:\GPImage\HandleImage\model\iris_model.ckpt-1000
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\10.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\100.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [1]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\BACK\1000.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1001.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1002.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1003.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1004.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\1005.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1006.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\1007.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1008.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1009.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\101.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1010.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1011.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1012.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\1013.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [1]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\BACK\1014.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1015.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1016.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1017.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1018.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1019.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\102.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1020.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\1021.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1022.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\1023.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1024.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1025.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\1026.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1027.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\1028.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1029.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [1]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\BACK\103.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1030.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\1031.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1032.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1033.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1034.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\1035.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1036.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\1037.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [1]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\BACK\1038.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1039.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [3]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\FACE\104.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1040.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1041.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1042.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [1]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\BACK\1043.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1044.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\1045.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [2]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\EYE\1046.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [4]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\LEFT\1047.png 保存文件路径
# 输入数据获取完毕
# -----------------------
# 运算开始
# -----------------------
# 运算结束，输出预测
# [5]
# -----------保存图片准备-----------
# E:\GPImage\HandleImage\HandleEnhanceImage\UP\